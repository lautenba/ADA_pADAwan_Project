# %%
from pathlib import Path
import shutil

import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import locale
#from html.parser import HTMLParser
# import website_func.py to use its functions
from website_func import *
from scrap import *
import os #To read the file
#reload every module each time
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Some quick analysis of the data
# We received a data set of .html file containing the website content of recipes.
# We wanted to sort them by website, in order to, more easily, find a pattern among them. This will enable us to do the "scraping" of the pages. First we thought about moving the files in a folder corresponding to their website, but it would be a waste of time and a big computational effort. Thus, we came up with a (probably) faster solution : we could simply write the name of the file within its corresponding website folder. By inspecting the files, we saw that the first line was always containing a comment with the name of the file and the complete website. Using readlines and split, we could easily retrieve the name of the website.
#
# We launched this process, but an alarm appeared describing a Trojan virus in the file "1c2cb6f0df04cf5a9d0baa116c6aa7bb.html".
# We had then to quarantine or maybe remove the file, as we have quite enough data.
# By doing so, we remarked the file "msg.log" that could help us into fastering the processus as its content is formed of the name of the file together with its website.

# %%
with open("recipePages/msg.log", 'r') as f:
    first_lines = f.readlines()[45:49]
    print(*first_lines, sep="--")
# Out:
# 59b9d3c43ee8df52fcd04128475059f5.html	http://allrecipes.com/Recipe/bacon-and-potato-soup/detail.aspx	2012-09-09 10:55:41 URL:http://allrecipes.com/Recipe/bacon-and-potato-soup/detail.aspx [225697/225697] -> "59b9d3c43ee8df52fcd04128475059f5.tmp" [1]
# --129b4dad66e6d0d59bbc6f3200f9e927.html	http://familyoven.com/recipes/search?terms=Dairy%20Free%20Alfredo%20Sauce	2012-09-09 10:55:42 URL:http://familyoven.com/recipes/search?terms=Dairy%20Free%20Alfredo%20Sauce [77640] -> "129b4dad66e6d0d59bbc6f3200f9e927.tmp" [1]
# --bafcd30bc137238af0cd9954f7d0701e.html	http://www.yummly.com/recipes/chicken-brunswick-stew-lima-beans	Syntax error in Set-Cookie: fbsr_54208124338=""; Expires=Thu, 01-Jan-1970 00:00:10 GMT; Path=/, JSESSIONID=27D73083292D7FE540727DC4AD6C50D2; Path=/; HttpOnly, yv="lJSpLE5cHmHHgrNrJgtM/w=="; Version=1; Max-Age=31536000; Expires=Mon, 09-Sep-2013 17:55:42 GMT; Path=/ at position 120.
# --2012-09-09 10:55:43 URL:http://www.yummly.com/recipes/chicken-brunswick-stew-lima-beans [286650] -> "bafcd30bc137238af0cd9954f7d0701e.tmp" [1]

# %% [markdown]
# We observed that occasionally a line containing other info that are not necessary can appear (in the example above, this is the case in the last line). Those lines are ignored during the sorting process.
# Also we noticed there are no file extensions other than .html and .log (see below). Thus, we know exacty what the contents of the folder recipePages are.

# %%
# We can find in the folder that, excepted the html files, there is only the log
# Get all filenames (i.e. path) that are in recipePages folder 
pathlist = Path("recipePages/").glob('**/*')
i = 0
for path in pathlist:
     # because path is object not string
    path_in_str = str(path)
    if not path_in_str.endswith(".html"):
        print(path_in_str)
# Out:
# recipePages\msg.log

# %% [markdown]
# ##### Sorting part of the content of the folder "recipePages" :

# %%
# If override True -> delete SortedFiles and re-execute the function (long)
sort_website_from_log(override=False)
# Out:
# Finished sorting the files

# %% [markdown]
# After the sorting comes the scraping part. In order to have the maximum number of data and to save some time, we'll first scrap the websites containing the higher number of files.

# %%
website_count=pd.Series()

for (root,dirs,files) in os.walk('SortedFiles', topdown="True"):   
        for website in dirs:
            if website == ".ipynb_checkpoints":
                continue
            filename = "SortedFiles/" + website +"/filesName.txt"
            
            f = open(filename, "r")
            number_of_link = len(f.readlines())
            line_to_add=pd.Series(number_of_link,index=[website])
            website_count = website_count.append(line_to_add)

# %%
#print(website_count)
print("Number of website with more than 1000 files:", len(website_count[website_count.values >1000]))
print("Number of website with less than 1000 files:", len(website_count[website_count.values <1000]))
# Out:
# Number of website with more than 1000 files: 19
# Number of website with less than 1000 files: 85

# %% [markdown]
# As we can observe, 19 websites have a really high number of files, higher than a thousand. The number of the files of those domains represents 53% of the total number of files.Those are the ones that we'll focus our attention on.

# %%
website_count.sort_values(ascending=False,inplace=True)
website_count_used=website_count[website_count.values>1000]
print(website_count_used)
total_number_files = website_count_used.values.sum()
chosen_number_files = website_count_used[0:3].values.sum()

print("Number of files in the 3 first domains : ", chosen_number_files)
print("Percentage of chosen files among the total: ", chosen_number_files/total_number_files)
# Out:
# allrecipes.com             28355
# food.com                   14661
# foodnetwork.com            11997
# yummly.com                  6590
# cooks.com                   5547
# epicurious.com              5060
# tasteofhome.com             4820
# myrecipes.com               3805
# recipes.sparkpeople.com     3671
# cdkitchen.com               2584
# bettycrocker.com            2325
# cookeatshare.com            2044
# southernfood.about.com      2012
# grouprecipes.com            1916
# recipe.com                  1460
# kraftrecipes.com            1420
# eatingwell.com              1400
# ifood.tv                    1295
# delish.com                  1050
# dtype: int64
# Number of files in the 3 first domains :  55013
# Percentage of chosen files among the total:  0.539279692585186

# %%
website_list_used=website_count_used.index.tolist()

# %%
#Words that have to be removed from the string in the website to keep only the ingredient:
list_ingredient_to_remove = ["of","teaspoon" , "cup", "cups","teaspoons","ounce","ounces","pounds","pound","tablespoons","chopped","quarts","fresh",\
                            "light","plain","popped","medium","shredded","bunch","tablespoon","to","taste","pinch","freshly","ground",\
                            "canned","carcass","cubes","dried","frozen","all","purpose","grated","minced","degree","degrees","optional",\
                            "jar","quartered","marinated","strips","strip","asian","stalks","package","can","cans","box","container",\
                            "evaporated","bottle","cans","extract","squares","german","slices","crushed","uncooked","seasoning","small",\
                            "sweet","packed","sliced","heavy","condensed","finely","long","grain","sweetened","firmly","cooked","crusts","lean",\
                            "caps","mix","steaks","large","instant","crumbs","semisweet","distilled","packages","pint","miniature","preserves",\
                            "processed","chunky","prepared","seasoned","american","stock","top","sirloin","tip","peeled","spears","leaves",\
                            "belgian","bob","italian","bottles","boneless","roast","breast","meat","tenderloins","granules","chips","converted",\
                            "containers","coleslaw","florets","cube","cubed","diced","crumbled","head","thighs","halves","drumsticks","blend",\
                            "leaf","bow","tie","stuffing","dry","boiling","cover","coarse","kosher","extra","virgin","fat","free","fluid","hot",\
                            "chops","loin","shoulder","roasted","for","frying","diced","thawed","bone","hocks","shucked","leftover","corned",\
                            "weed","summer","wild","whole","very","ripe","unbaked","crust","unsalted","unsifted","unsweetened","drops","drop",\
                            "paste","thickly","swiss","skinless","flavored","quart","puff","kernels","kernel","cracked","as","tortillas","chunk",\
                            "dash","dark","hash","brown","hashbrown","hungarian","rinsed","thin","thinly","thick","stewed","cleaned","gelatin",\
                            "sifted","skim","slivered","sprigs","sage","roma","romano","pasta","reduced","sodium","refried","refrigerated",\
                            "portobello","nuggets","tater","pinto","pudding","pitted","pinches","relish","penne","deep","mild","melted",\
                            "maraschino","loaf","link","jumbo","inch","jars","jasmine","generous","gold","graham","granulated","fried","skins",\
                            "fire","firm","flaked","flank","family","size","eagle","curd","half","russet","round","vidalia","unbleached","toll",\
                            "morsels","toasted","square","soft","sharp","serrano","seedless","old","provolone","process","premium","pouch","betty",\
                            "piri","chunks","smoked","other","original","breaded","tender","tenders","flowerets","nonfat","no","calorie","tail",\
                            "greek","great","northern","southern","envelope","dill","cold","round","steak","brisket","baby","assorted"]

list_ingredient_to_remove = sorted(list_ingredient_to_remove)
#print(list_ingredient_to_remove)

# %% [markdown]
# Creation of the recipe data:

# %%
#Create the data from the information found on the HTML pages

recipe_data = pd.DataFrame(columns = ['Website','Recipe','Prepare time', 'Ranking', 'Reviews', 'Ingredients'])  
list_unique_ingredients = []
unique_ingredients_data = pd.DataFrame(columns = ['Ingredient','Count'])

for (root,dirs,files) in os.walk('recipePagesT', topdown="True"):  
    for webpage in files:
        filename= 'recipePagesT/'+webpage
        
        #Try to open it, and if it doesn't, we don't analyse this webpage
        try:
            f = open(filename,'r')
            first_line=f.readline()
            f.close()
        except:
            print("We can't read the page: ",filename)
            continue

        website = str(first_line).split("/")[2].strip("www.")
        
        #Determine if we have to spare the data
        if website in website_list_used :
            
            #Read the data from the first website (allrecipes.com)
            if website in website_list_used[0]:
                recipe_data, list_unique_ingredients, unique_ingredients_data = scrap_allrecipes(website, filename,list_ingredient_to_remove, \
                                            list_unique_ingredients, recipe_data,website_list_used,unique_ingredients_data)
            
            # Food.com
            if website in website_list_used[1]:
                print(" --- ", filename)
                recipe_data, list_unique_ingredients, unique_ingredients_data = scrap_food(website, filename,list_ingredient_to_remove, \
                                            list_unique_ingredients, recipe_data,website_list_used,unique_ingredients_data)
                #print('\n')
            if website in website_list_used[2]:
                #recipe_data, list_unique_ingredients1, unique_ingredients_data1
                recipe_data, list_unique_ingredients, unique_ingredients_data = scrap_foodnetwork(website, filename,list_ingredient_to_remove,list_unique_ingredients, recipe_data,website_list_used,unique_ingredients_data)
                #print('\n')
print(list_unique_ingredients)
# Out:
# We can't read the page:  recipePagesT/0000758edcc24c88341ca0cd779f69b0.html
# We don't care about this page (foodnetwork):  recipePagesT/000255456bafed9c5783bff87cc0b27c.html
#  ---  recipePagesT/0003337e9b486449ab73322bba12ab28.html
# rating <li class="current-rating" style="width: 98.60%;"></li>
# rating 4.93
# Reviews : 100
#  ---  recipePagesT/00068f9b58c41919e2a7b1fa4d462ab0.html
# rating <li class="current-rating" style="width: 100.00%;"></li>
# rating 5.0
# Reviews : 2
# We don't care about this page:  recipePagesT/00159b3caa005f435b2f2f6cb4e1c2b5.html
# We don't care about this page (foodnetwork):  recipePagesT/001ec670080a960a6fbcc5e4dd20b8cc.html
# We don't care about this page (foodnetwork):  recipePagesT/001f044d051cf4f44ec53524a1a45bd8.html
#  ---  recipePagesT/002a198a301079842375d557645e23bf.html
# rating <li class="current-rating" style="width: 91.40%;"></li>
# rating 4.57
# Reviews : 67
# We don't care about this page (foodnetwork):  recipePagesT/0032c0e5c5097f07698665c4b92c31fe.html
# We can't read the page:  recipePagesT/0033dbc11a8c89f825af6ab3317d108e.html
# We don't care about this page (foodnetwork):  recipePagesT/00341ca30fd1c405aac95cd1bcf13a6d.html
#  ---  recipePagesT/00350ad22325c4273a947c9a8204a53e.html
# rating <li class="current-rating" style="width: 98.00%;"></li>
# rating 4.9
# Reviews : 221
#  ---  recipePagesT/009cae3d31565aaab689ca5e9dcc0413.html
# rating <li class="current-rating" style="width: 86.60%;"></li>
# rating 4.33
# Reviews : 3
# We don't care about this page:  recipePagesT/00a1d99a6383cdeac3d6c253f8e7cff1.html
# We don't care about this page (foodnetwork):  recipePagesT/00a5bfb5b2af5ae1c9716f9a9cff5aa1.html
# We don't care about this page:  recipePagesT/00a7450a98369de9097e042172e59fa4.html
#  ---  recipePagesT/00a9c455b5ccf42bee3a11365ed7e16a.html
# rating <li class="current-rating" style="width: 82.20%;"></li>
# rating 4.11
# Reviews : 9
# We can't read the page:  recipePagesT/00ad09075dfdaf485226fa532875e901.html
#  ---  recipePagesT/00afe1a62e4d553763db9a9624636141.html
# rating <li class="current-rating" style="width: 100.00%;"></li>
# rating 5.0
# Reviews : 3
#  ---  recipePagesT/00b120b30db6c66ff4917f62c9a53105.html
# rating <li class="current-rating" style="width: 0.00%;"></li>
# rating 0.0
# Reviews : 0
#  ---  recipePagesT/00b352fd67f34239a9bf3729756dad81.html
# We don't care about this page:  recipePagesT/00b352fd67f34239a9bf3729756dad81.html
#  ---  recipePagesT/00ba804c8e014ec66c9463f2b26030fd.html
# rating <li class="current-rating" style="width: 95.00%;"></li>
# rating 4.75
# Reviews : 175
# We don't care about this page:  recipePagesT/00bd78a7daa32aecada051639a3e029e.html
# We don't care about this page (foodnetwork):  recipePagesT/00bd80e99b69997d697f2fd257bdc726.html
# We don't care about this page (foodnetwork):  recipePagesT/00bdf24872f1b7dbbd36550361902182.html
#  ---  recipePagesT/00c16380158f3fd8b38ebff34cfee581.html
# rating <li class="current-rating" style="width: 100.00%;"></li>
# rating 5.0
# Reviews : 1
#  ---  recipePagesT/00c1927fff4e4fe7190d863118781f58.html
# rating <li class="current-rating" style="width: 100.00%;"></li>
# rating 5.0
# Reviews : 1
#  ---  recipePagesT/00d3b3165b6883390ab5a84f392eee1c.html
# rating <li class="current-rating" style="width: 70.00%;"></li>
# rating 3.5
# Reviews : 9
# We don't care about this page (foodnetwork):  recipePagesT/00d40b5797b3d467e1523f6bf2c8f5ac.html
#  ---  recipePagesT/00d73bb91ee497787b696b6ceb41095b.html
# rating <li class="current-rating" style="width: 91.60%;"></li>
# rating 4.58
# Reviews : 39
# We don't care about this page:  recipePagesT/00d94e3c80215d3757282b09f211474e.html
#  ---  recipePagesT/00dcfb044c09aa2ab8f49e7248cd42ea.html
# rating <li class="current-rating" style="width: 96.00%;"></li>
# rating 4.8
# Reviews : 6
#  ---  recipePagesT/00e3b36e1a072114bb1357d79ac217dd.html
# rating <li class="current-rating" style="width: 100.00%;"></li>
# rating 5.0
# Reviews : 1
#  ---  recipePagesT/00e68236c47983111857e994d18b0dcc.html
# rating <li class="current-rating" style="width: 100.00%;"></li>
# rating 5.0
# Reviews : 3
#  ---  recipePagesT/00eb8c139e384bbc561a39d0c7a593df.html
# rating <li class="current-rating" style="width: 91.40%;"></li>
# rating 4.57
# Reviews : 50
# ['butter', 'shallot', 'flour', 'jigger sherry', 'beef consomme', 'deli beef', 'grill', 'torpedo sandwich rolls', 'metric', 'salted peanuts', 'cayenne pepper', 'garlic powder', 'salt', 'chicken wings', 'pepper sauce', 'orange zest', 'sugar', 'cognac', 'brandy', 'white rice', 'cinnamon', 'milk', 'white sugar', 'wheat', 'white flour', 'white pepper', 'black pepper', 'chicken', 'canola oil', 'olive oil', 'chicken broth', 'lemon juice', 'artichoke hearts', 'capers', 'parsley', 'corn syrup', 'margarine', 'water', 'marshmallows', 'popcorn', 'pumpkin puree unseasoned', 'almond milk', 'raisins', 'pumpkin pie spice', 'cinnamon plus cardamom plus cloves', 'quick cooking oatmeal the', 'pepitas', 'honey', 'maple sugar', 'cream', 'pepper', 'mushrooms', 'cloves garlic', 'balsamic vinegar', 'bay', 'thyme', 'cumin seed', 'green chile pepper', 'turmeric', 'mustard greens', 'spinach', 'cumin', 'coriander', 'turkey', 'onion', 'tomatoes', 'kidney beans drained', 'garlic', 'chili powder', 'paprika', 'oregano', 'red wine vinegar', 'rice wine vinegar', 'soy sauce', 'pineapple juice', 'jalapeno chiles', 'piece ginger', 'red bell pepper', 'yellow bell pepper', 'steamed snow peas', 'mint', 'cilantro', 'chicken breasts', 'steamed rice', 'baking powder', 'eggs', 'vanilla', 'whipping cream', 'jalapeno peppers', 'basil', 'red pepper flakes', 'drain', 'reserve liquid', 'black drain', 'rice', 'bacon', 'green beans', 'new potatoes', 'goya olive oil', 'beef', 'yellow onion', 'goya tomato sauce', 'goya spanish olives stuffed', 'pimientos', 'goya sofrito', 'packet sazon goya', 'annatto', 'goya garlic', 'goya oregano', 'goya black pepper', 'goya discos', 'goya corn oil', 'dinner roll dough', 'butterscotch', 'walnuts', 'green bell peppers', 'cornstarch', 'bananas', 'baking soda', 'lemon rind', 'artificial sweetener', 'vegetable cooking spray', 'beef broth', 'carrots', 'stalk celery', 'celery seed', 'clove garlic', 'potatoes', 'corn', 'peas', 'gallon vegetable broth', 'sea salt', 'rosemary', 'savory', 'gallon ice water', 'dish pie', 'cream mushroom soup', 'green peas', 'chicken bouillon', 'plus flour', 'sticks butter', 'muscavado sugar', 'pure vanilla', 'block chocolate', 'block milk chocolate', 'ginger', 'cloves', 'pumpkin puree', 'carnation milk', 'lemons', 'chickpeas', 'tahini', 'butte', 'eggs at room temperature', 'good cocoa', 'good white chocolate', 'beef bouillon', 'seafood', 'worcestershire sauce', 'soup crabs', 'celery', 'lima beans', 'cabbage', 'red potato', 'lump crabmeat', 'claw crabmeat', 'cream cheese', 'orange juice', 'oranges', 'squeezed orange juice', 'stem strawberries', 'chocolate', 'baking potato', 'cheddar cheese', 'rolled oats', 'cinnamon sugar', 'asparagus', 'cooking spray', 'onion powder', 'baking flour', 'garbanzo bean flour', 'tapioca starch', 'xanthan gum', 'parmesan cheese', 'lukewarm water', 'active yeast', 'egg', 'apple cider vinegar', 'warm water', 'shortening', 'garlic cloves', 'red wine', 'green pepper', 'walnut pieces', 'cajun', 'monkfish fillets', 'tomato', 'white wine', 'white cooking wine', 'pear juice', 'sesame oil', 'green onion', 'sesame seeds', 'broccoli', 'cheese sauce', 'vegetable oil spray misting', 'food cake', 'food', 'cherry pie filling', 'pure almond', 'tomato sauce', 'white vinegar', 'peaches', 'lemon', 'tightly sugar', 'golden raisins', 'butternut squash', 'buttermilk', 'chives', 'green chilies', 'black beans', 'cut filet mignons', 'goose', 'duck liver', 'pastry', 'mushroom duxelles', 'egg beaten', 'water make an egg wash', 'bread', 'oil', 'mayonnaise', 'horseradish', 'sour cream', 'mustard', 'cottage cheese', 'cider vinegar', 'walnut oil', 'endives', 'apple', 'stemmed watercress', 'blue cheese', 'zucchini', 'pineapple', 'chicken liver', 'cooking sherry', 'mace', 'back bacon', 'ham', 'pumpkin', 'nutmeg', 'pie', 'cheese', 'cranberries', 'cauliflower', 'white wine vinegar', 'wasabi', 'tuna', 'sausage', 'coconut', 'ramen noodle soup', 'almonds', 'salad oil', 'green cabbage', 'vitamin c', 'and peaches', 'salmon fillets', ...

# %%
recipe_data
# Out:
#             Website                                             Recipe  \
# 0   foodnetwork.com                              French Dip Sandwiches
# 1          food.com  Halloween Party Treat (Candy Corn and Peanut Mix)
# 2    allrecipes.com                                Baked Buffalo Wings
# 3          food.com                             Homemade Grand Marnier
# 4    allrecipes.com                                  Fast Rice Pudding
# ..              ...                                                ...
# 70         food.com          Baked Salmon With Red Potatoes and Squash
# 71   allrecipes.com                            Tomato Mozzarella Salad
# 72         food.com                           Al Bussell Peach Cobbler
# 73   allrecipes.com        Jerky Lover's Jerky - Sweet, Hot and Spicy!
# 74         food.com                                Steak Wine Marinade
#
#    Prepare time Ranking Reviews  \
# 0            15       5     127
# 1            10    4.93     100
# 2           120     4.4     519
# 3            15       5       2
# 4            15     4.1      75
# ..          ...     ...     ...
# 70           80       5       1
# 71           10     5.0       5
# 72           65       5       3
# 73          310     4.7     122
# 74            5    4.57      50
#
#                                           Ingredients
# 0   [butter, shallot, flour, jigger sherry, beef c...
# 1                            [metric, salted peanuts]
# 2   [flour, cayenne pepper, garlic powder, salt, c...
# 3        [metric, orange zest, sugar, cognac, brandy]
# 4           [white rice, cinnamon, milk, white sugar]
# ..                                                ...
# 70  [metric, salmon fillets, zucchini, lemon, garl...
# 71  [tomatoes, mozzarella cheese, olive oil, balsa...
# 72  [metric, butter, flour, sugar, salt, baking po...
# 73  [onion powder, garlic powder, black pepper, be...
# 74  [metric, red wine, lemon juice, oregano, cumin...
#
# [75 rows x 6 columns]

# %%
copy_check = ['wheat', 'white flour', 'salt', 'white pepper', 'black pepper', 'chicken', 'canola oil', 'olive oil', 'chicken broth', 'lemon juice', 'artichoke hearts', 'capers', 'butter', 'parsley', 'corn syrup', 'margarine', 'water', 'sugar', 'marshmallows', 'popcorn', 'cream cheese', 'orange zest', 'orange juice', 'walnuts', 'baking potato', 'cheddar cheese', 'rolled oats', 'milk', 'pumpkin puree', 'pumpkin pie spice', 'cinnamon sugar', 'asparagus', 'cooking spray', 'pepper', 'soy sauce', 'balsamic vinegar', 'bay', 'onion', 'shallots', 'chicken bouillon', 'potatoes', 'corn', 'cream', 'baking flour', 'garbanzo bean flour', 'cornstarch', 'tapioca starch', 'baking powder', 'xanthan gum', 'oregano', 'parmesan cheese', 'white sugar', 'lukewarm water', 'active yeast', 'egg', 'apple cider vinegar', 'garlic', 'flour', 'warm water', 'shortening', 'cajun', 'monkfish fillets', 'cloves garlic', 'tomato', 'mushrooms', 'white wine', 'beef', 'white cooking wine', 'pear juice', 'sesame oil', 'green onion', 'sesame seeds', 'broccoli', 'cream of mushroom soup', 'rice', 'cheese sauce', 'tomatoes', 'tomato sauce', 'beef bouillon', 'carrots', 'white vinegar', 'cabbage', 'bread', 'cayenne pepper', 'oil', 'mayonnaise', 'horseradish', 'sour cream', 'worcestershire sauce', 'mustard', 'cottage cheese', 'clove garlic', 'cider vinegar', 'walnut oil', 'endives', 'apple', 'stemmed watercress', 'blue cheese', 'zucchini', 'pineapple juice', 'vanilla', 'pineapple', 'chicken liver', 'cooking sherry', 'mace', 'pumpkin', 'cinnamon', 'ginger', 'nutmeg', 'pie', 'cranberries', 'white wine vinegar', 'wasabi', 'cilantro', 'tuna', 'sausage', 'green pepper', 'coconut', 'baking soda', 'ramen noodle soup', 'almonds', 'salad oil', 'mozzarella cheese', 'basil', 'onion powder', 'garlic powder', 'teriyaki sauce', 'liquid smoke flavoring', 'red pepper flakes', 'pastry shells', 'green beans', 'garlic chili sauce', 'honey', 'vegetable cooking spray', 'or chicken', 'cream of celery soup', 'molasses', 'corn oil', 'cloves', 'allspice', 'nonstick cooking spray', 'ziti', 'vegetable oil', 'yellow squash', 'spinach', 'vegetable sauce', 'alfredo sauce', 'acorn squash', 'celery', 'oysters', 'bread flour', 'cornmeal', 'egg white', 'poppy seeds', 'juice', 'lemon', 'ginger root', 'cumin', 'coriander', 'pork', 'tea bags', 'peaches', 'stevia powder', 'red bell pepper', 'green bell pepper', 'red pepper', 'chile', 'apple juice', 'oats', 'raisins', 'red lentils', 'poultry', 'green lentils', 'jimmy hearty pork sausage crumbles', 'cheese', 'ricotta cheese', 'mushroom', 'strawberry', 'strawberries', 'banana', 'pie shells', 'cream of tartar', 'paprika', 'thyme', 'celery seed', 'tilapia fillets', 'white bread', 'biscuit baking', 'pecans', 'halibut', 'feta cheese', 'bacon', 'red onion', 'white rice', 'black drain', 'reserve liquid', 'chives', 'avocados', 'lime juice', 'pizza', 'cherry tomatoes', 'monterey jack cheese', 'brownie', 'peanut butter', 'chili powder', 'kidney beans', 'cannellini beans', 'chile sauce', 'beef broth', 'jalapeno pepper', 'fillets tilapia', 'bay tm', 'garlic salt', 'cauliflower', 'mashed banana', 'white cake', 'pistachio', 'carbonated beverage', 'whipped topping', 'cracker', 'chocolate', 'cream of chicken soup', 'cheese food', 'snow peas', 'salad dressing', 'angel food cake', 'mahi mahi fillets', 'coconut milk', 'mango', 'pie shell', 'bok choy', 'oyster sauce', 'pepper sauce', 'barbeque sauce', 'peach', 'and tomatoes', 'whipping cream', 'vodka', 'beans', 'taco', 'vegetable broth', 'turnips', 'potato', 'garbanzo beans', 'turmeric', 'saffron', 'curry powder', 'couscous', 'and rice', 'pine nuts', 'and sour', 'triple sec', 'tequila', 'orange liqueur grand', 'limes', 'egg yolk', 'cornflakes cereal', 'eggplant', 'french sandwich rolls', 'buttermilk', 'dressing', 'limeade concentrate', 'cherries', 'lime', 'white onion', 'basil sauce', 'manicotti shells', 'rhubarb', 'wheat berries', 'tomatillos', 'enchilada sauce', 'green chile peppers', 'sandwich bread', 'vanilla vodka', 'amaretto liqueur', 'recipe pastry a single pie', 'ham', 'adobo', 'packet sazon', 'red potatoes', 'red wine', 'or bay', 'elbow macaroni', 'minestrone soup', 'mixed vegetables', 'meatloaf', 'cucumbers', 'lemon pepper', 'sauerkraut', 'kielbasa', 'navy beans', 'anise', 'brussels sprouts', 'dijon mustard', 'bulk pork breakfast sausage', 'pepperjack cheese', 'white hominy', 'black beans', 'tortilla', 'avocado', 'eggnog', 'rum', 'amaranth flour', 'tapioca flour', 'arrowroot flour', 'milk chocolate candy kisses', 'yellow onion', 'spaghetti sauce', 'tomato puree', 'recipe pastry a double pie', 'dates', 'linguini', 'clams', 'espresso coffee', 'gingerbread syrup', 'whipped cream', 'vanilla powder', 'wax beans', 'nuts', 'almond', 'rotini', 'black olives', 'green tomatoes', 'jicama', 'ketchup', 'rice vinegar', 'salsa', 'salt pork', 'egg noodles', 'iceberg lettuce', 'green peas', 'coconut cream', 'tamarind pulp', 'chickpea flour', 'coriander seed', 'mustard seed', 'black peppercorns', 'greens', 'yogurt', 'ice', 'green salsa', 'chow mein noodles', 'mint', 'spaghetti', 'croutons', 'crabmeat', 'lobster', 'garlic pepper', 'lemon grass', 'bulb garlic', 'red chile pepper', 'bunches cilantro', 'wonton wrappers', 'plump lemongrass stalk', 'curry', 'thai basil', 'pickle', 'lamb', 'chili sauce', 'wax pepper', 'garam masala', 'yellow food coloring', 'red food coloring', 'pattypan squash', 'rosemary', 'lamb rump', 'red wine vinegar', 'yellow bell pepper', 'and turkey', 'lasagna noodles', 'collard greens', 'acini di pepe', 'mandarin oranges', 'green olives', 'salami', 'green cardamom pods', 'gallon milk', 'mixed greens', 'nectarines', 'grapefruit', 'honey balsamic', 'strawberries in syrup', 'water chestnuts', 'vegetable soup', 'sauce', 'canning', 'lids', 'rings', 'carrot', 'habanero peppers', 'pouches liquid pectin', 'cake flour', 'whipped cream cheese', 'beer', 'and', 'tofu', 'rice noodles', 'butter shortening', 'turkey', 'kale', 'hubbard squash cut into', 'seeds removed', 'apple pie spice', 'salted butter', 'onion soup', 'or ginger ale', 'moist white cake', 'coffee powder', 'coffee', 'coffee liqueur', 'mascarpone cheese', 'cocoa powder', 'thousand island dressing', 'breakfast sausage', 'liquid', 'shrimp', 'blue cheese salad dressing', 'cayenne pepper sauce', 'buffalo wing sauce', 'chicken in water', 'vegetables', 'and potatoes', 'into', 'gravy', 'tips', 'burgundy wine', 'shallot', 'buttery crackers', 'grape jelly', 'rigatoni', 'cream of tomato soup', 'pizza sauce', 'pepperoni sausage', 'lime sherbet', 'ginger ale', 'marshmallow creme', 'tahini', 'sourdough bread', 'imitation crabmeat', 'blackberries', 'raspberries', 'blueberries', 'new mexico chile pods', 'cotija cheese', 'green grapes', 'red grapes', 'flat beer', 'yeast', 'and mashed potatoes', 'rice wine vinegar', 'creamy peanut butter', 'green cabbage', 'red cabbage', 'napa cabbage', 'spaghetti noodles', 'red pepper sauce', 'individually wrapped caramels', 'pecan', 'cheddar', 'sour cream mashed potatoes', 'fully ham', 'bacon flavor bits', 'crescent dinner rolls', 'broken pieces vermicelli', 'leeks', 'tomato juice', 'clam juice', 'deveined', 'mussels', 'clams in shell', 'sea scallops', 'beef stew', 'barley', 'caraway seeds', 'orecchiette', 'plum tomatoes', 'yellow cake', 'granny smith apples', 'sugar dusting', 'peppermint oil', 'any color food coloring', 'cooking oil', 'chile peppers', 'dinner rolls', 'butterscotch', 'tomato soup', 'less', 'vinegar', 'or broccoli', 'chile pepper', 'fillets tilapia fillets', 'seafood', 'wheat bread', 'white corn', 'yellow corn', 'pepper salmon', 'sweetener', 'style', 'cling peaches', 'stone cornmeal', 'pancakes', 'pancake', 'nutmeg whipped cream', 'corn flour', 'water needed', 'lukewarm milk', 'rye flour', 'phyllo dough', 'white chocolate', 'chocolate cake']

# %%
'''
ingredient_index = unique_ingredients_data[unique_ingredients_data['Ingredient']=='salt'].index[0]
unique_ingredients_data.at[ingredient_index,'Count']= unique_ingredients_data['Count'][ingredient_index] + 1
'''



#ingredients_ordered_alphabet = unique_ingredients_data.reindex(sorted(unique_ingredients_data['Ingredient']), axis=1).copy()

ingredients_ordered_alphabet = unique_ingredients_data.sort_values(by=['Ingredient'])

#print(ingredients_ordered_alphabet)


with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(ingredients_ordered_alphabet)
# Out:
#                       Ingredient Count
# 120                 active yeast     1
# 173                      almonds     1
# 71                       annatto     1
# 151                        apple     1
# 122          apple cider vinegar     2
# 20              artichoke hearts     1
# 110                    asparagus     2
# 114                 baking flour     1
# 104                baking potato     1
# 50                 baking powder     4
# 171                  baking soda     1
# 32              balsamic vinegar     4
# 57                         basil     2
# 33                           bay     3
# 64                          beef     6
# 137                beef bouillon     1
# 83                    beef broth     1
# 61                   black drain     1
# 14                  black pepper    13
# 153                  blue cheese     2
# 140                        bread     1
# 134                     broccoli     2
# 5                         butter    18
# 78                  butterscotch     1
# 139                      cabbage     1
# 125                        cajun     1
# 16                    canola oil     1
# 21                        capers     1
# 84                       carrots     2
# 1                 cayenne pepper     3
# 86                   celery seed     1
# 105               cheddar cheese     1
# 135                 cheese sauce     1
# 15                       chicken     4
# 100             chicken bouillon     2
# 18                 chicken broth     3
# 157                chicken liver     1
# 4                  chicken wings     1
# 47                  chili powder     1
# 148                cider vinegar     1
# 56                      cilantro     2
# 8                       cinnamon     3
# 109               cinnamon sugar     1
# 87                  clove garlic     3
# 31                 cloves garlic     4
# 170                      coconut     2
# 158               cooking sherry     1
# 111                cooking spray     1
# 41                     coriander     2
# 89                          corn     3
# 23                    corn syrup     1
# 82                    cornstarch     2
# 147               cottage cheese     1
# 164                  cranberries     1
# 113                        cream     1
# 101                 cream cheese     1
# 98        cream of mushroom soup     2
# 40                         cumin     2
# 35                    cumin seed     1
# 77             dinner roll dough     1
# 97                      dish pie     1
# 59                         drain     1
# 121                          egg     5
# 51                          eggs     1
# 150                      endives     1
# 0                          flour     9
# 96              gallon ice water     1
# 92        gallon vegetable broth     1
# 115          garbanzo bean flour     1
# 46                        garlic     6
# 2                  garlic powder     2
# 161                       ginger     1
# 74             goya black pepper     1
# 76                 goya corn oil     1
# 75                   goya discos     1
# 72                   goya garlic     1
# 63                goya olive oil     1
# 73                  goya oregano     1
# 69                  goya sofrito     1
# 67   goya spanish olives stuffed     1
# 66             goya tomato sauce     1
# 90                   green beans     1
# 81            green bell peppers     1
# 36            green chile pepper     1
# 132                  green onion     2
# 99                    green peas     1
# 169                 green pepper     1
# 143                  horseradish     1
# 55              jalapeno peppers     1
# 45          kidney beans drained     1
# 19                   lemon juice     2
# 178       liquid smoke flavoring     1
# 119               lukewarm water     1
# 159                         mace     1
# 24                     margarine     1
# 27                  marshmallows     1
# 142                   mayonnaise     1
# 9                           milk     6
# 126             monkfish fillets     1
# 175            mozzarella cheese     1
# 30                     mushrooms     3
# 146                      mustard     1
# 38                mustard greens     1
# 162                       nutmeg     1
# 141                          oil     1
# 17                     olive oil    12
# 43                         onion    10
# 176                 onion powder     1
# 103                 orange juice     2
# 102                  orange zest     1
# 49                       oregano     2
# 70             packet sazon goya     1
# 48                       paprika     1
# 118              parmesan cheese     1
# 22                       parsley     4
# 130                   pear juice     1
# 91                          peas     1
# 29                        pepper     7
# 6                   pepper sauce     1
# 163                          pie     1
# 68                     pimientos     1
# 156                    pineapple     1
# 155              pineapple juice     2
# 28                       popcorn     1
# 88                      potatoes     3
# 160                      pumpkin     1
# 108            pumpkin pie spice     1
# 107                pumpkin puree     1
# 172            ramen noodle soup     1
# 54               red bell pepper     1
# 58             red pepper flakes     2
# 60                reserve liquid     2
# 62                          rice     3
# 106                  rolled oats     1
# 94                      rosemary     1
# 174                    salad oil     1
# 3                           salt    23
# 168                      sausage     1
# 95                        savory     1
# 93                      sea salt     1
# 131                   sesame oil     1
# 133                 sesame seeds     2
# 112                     shallots     2
# 124                   shortening     1
# 144                   sour cream     1
# 80                     soy sauce     6
# 39                       spinach     1
# 85                  stalk celery     1
# 152           stemmed watercress     1
# 26                         sugar     6
# 116               tapioca starch     1
# 177               teriyaki sauce     1
# 34                         thyme     2
# 127                       tomato     1
# 136                 tomato sauce     2
# 44                      tomatoes     6
# 167                         tuna     1
# 42                        turkey     1
# 37                      turmeric     1
# 52                       vanilla     4
# 149                   walnut oil     1
# 79                       walnuts     3
# 123                   warm water     1
# 166                       wasabi     1
# 25                         water     7
# 11                         wheat     1
# 53                whipping cream     1
# 129           white cooking wine     1
# 12                   white flour     1
# 13                  white pepper     1
# 7                     white rice     1
# 10                   white sugar    13
# 138                white vinegar     1
# 128                   white wine     2
# 165           white wine vinegar     1
# 145         worcestershire sauce     3
# 117                  xanthan gum     1
# 65                  yellow onion     1
# 154                     zucchini     1

# %%
list_all_ingredients = []
for data in recipe_data['Ingredients']:
    #print(data)    
    #ingredients_strip = data.strip()
    for i in range(len(data)):
        list_all_ingredients.append(data[i])
    
    
print(len(list_all_ingredients))
list_unique_ingredients = set(list_all_ingredients)
print(len(list_unique_ingredients))
set(list_unique_ingredients)
# Out:
# 2605
# 510
# {'acini di pepe',
#  'acorn squash',
#  'active yeast',
#  'adobo',
#  'alfredo sauce',
#  'allspice',
#  'almond',
#  'almonds',
#  'amaranth flour',
#  'amaretto liqueur',
#  'and',
#  'and mashed potatoes',
#  'and potatoes',
#  'and rice',
#  'and sour',
#  'and tomatoes',
#  'and turkey',
#  'angel food cake',
#  'anise',
#  'any color food coloring',
#  'apple',
#  'apple cider vinegar',
#  'apple juice',
#  'apple pie spice',
#  'arrowroot flour',
#  'artichoke hearts',
#  'asparagus',
#  'avocado',
#  'avocados',
#  'bacon',
#  'bacon flavor bits',
#  'baking flour',
#  'baking potato',
#  'baking powder',
#  'baking soda',
#  'balsamic vinegar',
#  'banana',
#  'barbeque sauce',
#  'barley',
#  'basil',
#  'basil sauce',
#  'bay',
#  'bay tm',
#  'beans',
#  'beef',
#  'beef bouillon',
#  'beef broth',
#  'beef stew',
#  'beer',
#  'biscuit baking',
#  'black beans',
#  'black drain',
#  'black olives',
#  'black pepper',
#  'black peppercorns',
#  'blackberries',
#  'blue cheese',
#  'blue cheese salad dressing',
#  'blueberries',
#  'bok choy',
#  'bread',
#  'bread flour',
#  'breakfast sausage',
#  'broccoli',
#  'broken pieces vermicelli',
#  'brownie',
#  'brussels sprouts',
#  'buffalo wing sauce',
#  'bulb garlic',
#  'bulk pork breakfast sausage',
#  'bunches cilantro',
#  'burgundy wine',
#  'butter',
#  'butter shortening',
#  'buttermilk',
#  'butterscotch',
#  'buttery crackers',
#  'cabbage',
#  'cajun',
#  'cake flour',
#  'cannellini beans',
#  'canning',
#  'canola oil',
#  'capers',
#  'caraway seeds',
#  'carbonated beverage',
#  'carrot',
#  'carrots',
#  'cauliflower',
#  'cayenne pepper',
#  'cayenne pepper sauce',
#  'celery',
#  'celery seed',
#  'cheddar',
#  'cheddar cheese',
#  'cheese',
#  'cheese food',
#  'cheese sauce',
#  'cherries',
#  'cherry tomatoes',
#  'chicken',
#  'chicken bouillon',
#  'chicken broth',
#  'chicken in water',
#  'chicken liver',
#  'chickpea flour',
#  'chile',
#  'chile pepper',
#  'chile peppers',
#  'chile sauce',
#  'chili powder',
#  'chili sauce',
#  'chives',
#  'chocolate',
#  'chocolate cake',
#  'chow mein noodles',
#  'cider vinegar',
#  'cilantro',
#  'cinnamon',
#  'cinnamon sugar',
#  'clam juice',
#  'clams',
#  'clams in shell',
#  'cling peaches',
#  'clove garlic',
#  'cloves',
#  'cloves garlic',
#  'cocoa powder',
#  'coconut',
#  'coconut cream',
#  'coconut milk',
#  'coffee',
#  'coffee liqueur',
#  'coffee powder',
#  'collard greens',
#  'cooking oil',
#  'cooking sherry',
#  'cooking spray',
#  'coriander',
#  'coriander seed',
#  'corn',
#  'corn flour',
#  'corn oil',
#  'corn syrup',
#  'cornflakes cereal',
#  'cornmeal',
#  'cornstarch',
#  'cotija cheese',
#  'cottage cheese',
#  'couscous',
#  'crabmeat',
#  'cracker',
#  'cranberries',
#  'cream',
#  'cream cheese',
#  'cream of celery soup',
#  'cream of chicken soup',
#  'cream of mushroom soup',
#  'cream of tartar',
#  'cream of tomato soup',
#  'creamy peanut butter',
#  'crescent dinner rolls',
#  'croutons',
#  'cucumbers',
#  'cumin',
#  'curry',
#  'curry powder',
#  'dates',
#  'deveined',
#  'dijon mustard',
#  'dinner rolls',
#  'dressing',
#  'egg',
#  'egg noodles',
#  'egg white',
#  'egg yolk',
#  'eggnog',
#  'eggplant',
#  'elbow macaroni',
#  'enchilada sauce',
#  'endives',
#  'espresso coffee',
#  'feta cheese',
#  'fillets tilapia',
#  'fillets tilapia fillets',
#  'flat beer',
#  'flour',
#  'french sandwich rolls',
#  'fully ham',
#  'gallon milk',
#  'garam masala',
#  'garbanzo bean flour',
#  'garbanzo beans',
#  'garlic',
#  'garlic chili sauce',
#  'garlic pepper',
#  'garlic powder',
#  'garlic salt',
#  'ginger',
#  'ginger ale',
#  'ginger root',
#  'gingerbread syrup',
#  'granny smith apples',
#  'grape jelly',
#  'grapefruit',
#  'gravy',
#  'green beans',
#  'green bell pepper',
#  'green cabbage',
#  'green cardamom pods',
#  'green chile peppers',
#  'green grapes',
#  'green lentils',
#  'green olives',
#  'green onion',
#  'green peas',
#  'green pepper',
#  'green salsa',
#  'green tomatoes',
#  'greens',
#  'habanero peppers',
#  'halibut',
#  'ham',
#  'honey',
#  'honey balsamic',
#  'horseradish',
#  'hubbard squash cut into',
#  'ice',
#  'iceberg lettuce',
#  'imitation crabmeat',
#  'individually wrapped caramels',
#  'into',
#  'jalapeno pepper',
#  'jicama',
#  'jimmy hearty pork sausage crumbles',
#  'juice',
#  'kale',
#  'ketchup',
#  'kidney beans',
#  'kielbasa',
#  'lamb',
#  'lamb rump',
#  'lasagna noodles',
#  'leeks',
#  'lemon',
#  'lemon grass',
#  'lemon juice',
#  'lemon pepper',
#  'less',
#  'lids',
#  'lime',
#  'lime juice',
#  'lime sherbet',
#  'limeade concentrate',
#  'limes',
#  'linguini',
#  'liquid',
#  'liquid smoke flavoring',
#  'lobster',
#  'lukewarm milk',
#  'lukewarm water',
#  'mace',
#  'mahi mahi fillets',
#  'mandarin oranges',
#  'mango',
#  'manicotti shells',
#  'margarine',
#  'marshmallow creme',
#  'marshmallows',
#  'mascarpone cheese',
#  'mashed banana',
#  'mayonnaise',
#  'meatloaf',
#  'milk',
#  'milk chocolate candy kisses',
#  'minestrone soup',
#  'mint',
#  'mixed greens',
#  'mixed vegetables',
#  'moist white cake',
#  'molasses',
#  'monkfish fillets',
#  'monterey jack cheese',
#  'mozzarella cheese',
#  'mushroom',
#  'mushrooms',
#  'mussels',
#  'mustard',
#  'mustard seed',
#  'napa cabbage',
#  'navy beans',
#  'nectarines',
#  'new mexico chile pods',
#  'nonstick cooking spray',
#  'nutmeg',
#  'nutmeg whipped cream',
#  'nuts',
#  'oats',
#  'oil',
#  'olive oil',
#  'onion',
#  'onion powder',
#  'onion soup',
#  'or bay',
#  'or broccoli',
#  'or chicken',
#  'or ginger ale',
#  'orange juice',
#  'orange liqueur grand',
#  'orange zest',
#  'orecchiette',
#  'oregano',
#  'oyster sauce',
#  'oysters',
#  'packet sazon',
#  'pancake',
#  'pancakes',
#  'paprika',
#  'parmesan cheese',
#  'parsley',
#  'pastry shells',
#  'pattypan squash',
#  'peach',
#  'peaches',
#  'peanut butter',
#  'pear juice',
#  'pecan',
#  'pecans',
#  'pepper',
#  'pepper salmon',
#  'pepper sauce',
#  'pepperjack cheese',
#  'peppermint oil',
#  'pepperoni sausage',
#  'phyllo dough',
#  'pickle',
#  'pie',
#  'pie shell',
#  'pie shells',
#  'pine nuts',
#  'pineapple',
#  'pineapple juice',
#  'pistachio',
#  'pizza',
#  'pizza sauce',
#  'plum tomatoes',
#  'plump lemongrass stalk',
#  'popcorn',
#  'poppy seeds',
#  'pork',
#  'potato',
#  'potatoes',
#  'pouches liquid pectin',
#  'poultry',
#  'pumpkin',
#  'pumpkin pie spice',
#  'pumpkin puree',
#  'raisins',
#  'ramen noodle soup',
#  'raspberries',
#  'recipe pastry a double pie',
#  'recipe pastry a single pie',
#  'red bell pepper',
#  'red cabbage',
#  'red chile pepper',
#  'red food coloring',
#  'red grapes',
#  'red lentils',
#  'red onion',
#  'red pepper',
#  'red pepper flakes',
#  'red pepper sauce',
#  'red potatoes',
#  'red wine',
#  'red wine vinegar',
#  'reserve liquid',
#  'rhubarb',
#  'rice',
#  'rice noodles',
#  'rice vinegar',
#  'rice wine vinegar',
#  'ricotta cheese',
#  'rigatoni',
#  'rings',
#  'rolled oats',
#  'rosemary',
#  'rotini',
#  'rum',
#  'rye flour',
#  'saffron',
#  'salad dressing',
#  'salad oil',
#  'salami',
#  'salsa',
#  'salt',
#  'salt pork',
#  'salted butter',
#  'sandwich bread',
#  'sauce',
#  'sauerkraut',
#  'sausage',
#  'sea scallops',
#  'seafood',
#  'seeds removed',
#  'sesame oil',
#  'sesame seeds',
#  'shallot',
#  'shallots',
#  'shortening',
#  'shrimp',
#  'snow peas',
#  'sour cream',
#  'sour cream mashed potatoes',
#  'sourdough bread',
#  'soy sauce',
#  'spaghetti',
#  'spaghetti noodles',
#  'spaghetti sauce',
#  'spinach',
#  'stemmed watercress',
#  'stevia powder',
#  'stone cornmeal',
#  'strawberries',
#  'strawberries in syrup',
#  'strawberry',
#  'style',
#  'sugar',
#  'sugar dusting',
#  'sweetener',
#  'taco',
#  'tahini',
#  'tamarind pulp',
#  'tapioca flour',
#  'tapioca starch',
#  'tea bags',
#  'tequila',
#  'teriyaki sauce',
#  'thai basil',
#  'thousand island dressing',
#  'thyme',
#  'tilapia fillets',
#  'tips',
#  'tofu',
#  'tomatillos',
#  'tomato',
#  'tomato juice',
#  'tomato puree',
#  'tomato sauce',
#  'tomato soup',
#  'tomatoes',
#  'tortilla',
#  'triple sec',
#  'tuna',
#  'turkey',
#  'turmeric',
#  'turnips',
#  'vanilla',
#  'vanilla powder',
#  'vanilla vodka',
#  'vegetable broth',
#  'vegetable cooking spray',
#  'vegetable oil',
#  'vegetable sauce',
#  'vegetable soup',
#  'vegetables',
#  'vinegar',
#  'vodka',
#  'walnut oil',
#  'walnuts',
#  'warm water',
#  'wasabi',
#  'water',
#  'water chestnuts',
#  'water needed',
#  'wax beans',
#  'wax pepper',
#  'wheat',
#  'wheat berries',
#  'wheat bread',
#  'whipped cream',
#  'whipped cream cheese',
#  'whipped topping',
#  'whipping cream',
#  'white bread',
#  'white cake',
#  'white chocolate',
#  'white cooking wine',
#  'white corn',
#  'white flour',
#  'white hominy',
#  'white onion',
#  'white pepper',
#  'white rice',
#  'white sugar',
#  'white vinegar',
#  'white wine',
#  'white wine vinegar',
#  'wonton wrappers',
#  'worcestershire sauce',
#  'xanthan gum',
#  'yeast',
#  'yellow bell pepper',
#  'yellow cake',
#  'yellow corn',
#  'yellow food coloring',
#  'yellow onion',
#  'yellow squash',
#  'yogurt',
#  'ziti',
#  'zucchini'}

# %%
recipe_data
# Out:
#             Website                                             Recipe  \
# 0    allrecipes.com  Chicken Breast Cutlets with Artichokes and Capers
# 1    allrecipes.com                            Best Ever Popcorn Balls
# 2    allrecipes.com                       Orange Cream Cheese Frosting
# 3    allrecipes.com                               Perfect Baked Potato
# 4    allrecipes.com                                    Pumpkin Oatmeal
# ..              ...                                                ...
# 288  allrecipes.com                               Peanut Butter Bars I
# 289  allrecipes.com                                   German Rye Bread
# 290  allrecipes.com                                     Spanakopita II
# 291  allrecipes.com                   White Chocolate Blondie Brownies
# 292  allrecipes.com                           Chocolate Mousse Cake IV
#
#     Ranking Reviews                                        Ingredients
# 0       4.4      80  [wheat, white flour, salt, white pepper, black...
# 1       4.4     322  [corn syrup, margarine, water, sugar, marshmal...
# 2       4.6      39  [cream cheese, butter, orange zest, orange jui...
# 3       4.7     410  [baking potato, olive oil, salt, butter, black...
# 4       3.9      88  [rolled oats, milk, pumpkin puree, pumpkin pie...
# ..      ...     ...                                                ...
# 288     4.6    1378  [butter, margarine, cracker, sugar, peanut but...
# 289     3.8      27  [active yeast, warm water, lukewarm milk, whit...
# 290     4.7     201  [vegetable oil, onion, spinach, flour, feta ch...
# 291     4.3      23  [butter, white chocolate, egg, white sugar, va...
# 292     4.6     240  [chocolate cake, milk, chocolate, water, choco...
#
# [293 rows x 5 columns]

# %%
# Out:
# wtf
# carrot
# '    \nlist_unique_ingredients.sort()\nlist_unique_ingredients\n'
